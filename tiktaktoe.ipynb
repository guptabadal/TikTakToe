# %%
#function
#print
def printTIK(board):
    print(board[1],"|",board[2],"|",board[3])
    print(board[4],"|",board[5],"|",board[6])
    print(board[7],"|",board[8],"|",board[9])
#chance of player
import random as rn
def chance(p1,p2):
    a=rn.randrange(p1,p2)
    if(a<30):        
        return 'player1'
    else:
        return 'player2'
#makring
def marker(ch):
    if ch=='x':
        return 'o'
    elif ch=='o':
        return 'x'
    else:
        print("wrong input")
#for checking the board
def checkboard(board):
    if(board[1]==board[2]==board[3] or
       board[4]==board[5]==board[6] or
       board[7]==board[8]==board[9] or
       board[1]==board[5]==board[9] or
       board[3]==board[5]==board[7] or
       board[1]==board[4]==board[7] or
       board[2]==board[5]==board[8] or
       board[3]==board[6]==board[9] == True):
        return True
    else:
        return False
       
        

    
#main
list=['#',1,2,3,4,5,6,7,8,9]
printTIK(list)
ch=chance(0,60)
print("chance of {}".format(ch))
mar1=input("what mark does {}  want x or o :".format(ch))
mar2=marker(mar1)
if ch=='player2':
    mar3=mar1
    mar4=mar2
    mar1=mar4
    mar2=mar3
print("player 1 mark {} and player 2 mark {}".format(mar1,mar2))
    
print("lets play the game")
loop=0
c=0
while loop==0:
    printTIK(list)
    if c<10:
        if ch=='player1':
            c=c+1
            markinput=int(input("where u want to mark {} player1=".format(mar1)))
            if markinput>10 :
                print("input valid no")
                continue
            list[markinput]=mar1
            cb=checkboard(list)
            if(cb==True):
                break
            ch='player2'
        elif ch=='player2':
            c=c+1
            markinput=int(input("where u want to mark {} player2=".format(mar2)))
            if markinput>10 :
                print("input valid no")
                continue
            list[markinput]=mar2
            cb=checkboard(list)
            if(cb==True):
                break
            ch='player1'
    else:
        loop=0  
if loop==1:
    printTIK(list)
    print("oops no one win")
else:
    printTIK(list)
    print("{} wins!!!! congo".format(ch))
# Out:
# 1 | 2 | 3
# 4 | 5 | 6
# 7 | 8 | 9
# chance of player2
